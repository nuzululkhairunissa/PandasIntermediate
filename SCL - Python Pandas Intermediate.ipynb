# %%
import pandas as pd
df = pd.read_csv('california_housing_test.csv')

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df.head(15)
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -122.05     37.37                27.0       3885.0           661.0
# 1     -118.30     34.26                43.0       1510.0           310.0
# 2     -117.81     33.78                27.0       3589.0           507.0
# 3     -118.36     33.82                28.0         67.0            15.0
# 4     -119.67     36.33                19.0       1241.0           244.0
# 5     -119.56     36.51                37.0       1018.0           213.0
# 6     -121.43     38.63                43.0       1009.0           225.0
# 7     -120.65     35.48                19.0       2310.0           471.0
# 8     -122.84     38.40                15.0       3080.0           617.0
# 9     -118.02     34.08                31.0       2402.0           632.0
# 10    -118.24     33.98                45.0        972.0           249.0
# 11    -119.12     35.85                37.0        736.0           166.0
# ...

# %%
df.tail(15)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2985    -120.47     34.94                17.0       1368.0           308.0
# 2986    -118.25     33.93                42.0        819.0           233.0
# 2987    -121.97     37.29                25.0       4096.0           743.0
# 2988    -122.01     36.97                43.0       2162.0           509.0
# 2989    -122.02     37.60                32.0       1295.0           295.0
# 2990    -118.23     34.09                49.0       1638.0           456.0
# 2991    -117.17     34.28                13.0       4867.0           718.0
# 2992    -122.33     37.39                52.0        573.0           102.0
# 2993    -117.91     33.60                37.0       2088.0           510.0
# 2994    -117.93     33.86                35.0        931.0           181.0
# 2995    -119.86     34.42                23.0       1450.0           642.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
# longitude             3000 non-null float64
# latitude              3000 non-null float64
# housing_median_age    3000 non-null float64
# total_rooms           3000 non-null float64
# total_bedrooms        3000 non-null float64
# population            3000 non-null float64
# households            3000 non-null float64
# median_income         3000 non-null float64
# median_house_value    3000 non-null float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
df.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
df['total_bedrooms']
# Out:
# 0        661.0
# 1        310.0
# 2        507.0
# 3         15.0
# 4        244.0
#          ...
# 2995     642.0
# 2996    1082.0
# 2997     201.0
# 2998      14.0
# 2999     263.0
# Name: total_bedrooms, Length: 3000, dtype: float64

# %%
columns = ['longitude','latitude','total_rooms']
df[columns]
# Out:
#       longitude  latitude  total_rooms
# 0       -122.05     37.37       3885.0
# 1       -118.30     34.26       1510.0
# 2       -117.81     33.78       3589.0
# 3       -118.36     33.82         67.0
# 4       -119.67     36.33       1241.0
# ...         ...       ...          ...
# 2995    -119.86     34.42       1450.0
# 2996    -118.14     34.06       5257.0
# 2997    -119.70     36.30        956.0
# 2998    -117.12     34.10         96.0
# 2999    -119.63     34.42       1765.0
#
# [3000 rows x 3 columns]

# %%
cond = df['median_income'] > 5
df[cond]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 14      -117.97     33.73                27.0       2097.0           325.0
# 18      -118.88     34.21                26.0       1590.0           196.0
# ...         ...       ...                 ...          ...             ...
# 2991    -117.17     34.28                13.0       4867.0           718.0
# 2992    -122.33     37.39                52.0        573.0           102.0
# 2993    -117.91     33.60                37.0       2088.0           510.0
# 2994    -117.93     33.86                35.0        931.0           181.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
smaller = df.iloc[3:7, 2:4]

# %%
smaller
# Out:
#    housing_median_age  total_rooms
# 3                28.0         67.0
# 4                19.0       1241.0
# 5                37.0       1018.0
# 6                43.0       1009.0

# %%
#extracting rows by a range
df.iloc[ 0:6]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
# 5    -119.56     36.51                37.0       1018.0           213.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0
# 5       663.0       204.0         1.6635             67000.0

# %%
#extracting columns by a range

df.iloc[:,0:3]
# Out:
#       longitude  latitude  housing_median_age
# 0       -122.05     37.37                27.0
# 1       -118.30     34.26                43.0
# 2       -117.81     33.78                27.0
# 3       -118.36     33.82                28.0
# 4       -119.67     36.33                19.0
# ...         ...       ...                 ...
# 2995    -119.86     34.42                23.0
# 2996    -118.14     34.06                27.0
# 2997    -119.70     36.30                10.0
# 2998    -117.12     34.10                40.0
# 2999    -119.63     34.42                42.0
#
# [3000 rows x 3 columns]

# %%
cond = df["population"] > 1500
df[cond]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 9       -118.02     34.08                31.0       2402.0           632.0
# 13      -117.03     32.97                16.0       3936.0           694.0
# 17      -121.20     38.69                26.0       3077.0           607.0
# 19      -122.59     38.01                35.0       8814.0          1307.0
# ...         ...       ...                 ...          ...             ...
# 2979    -117.91     34.09                20.0       4327.0          1037.0
# 2981    -120.66     35.49                17.0       4422.0           945.0
# 2984    -117.59     33.88                13.0       3239.0           849.0
# 2987    -121.97     37.29                25.0       4096.0           743.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
#
#       population  households  median_income  median_house_value
# ...

# %%
cond = df['population'] > 1500
cond
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2995    False
# 2996     True
# 2997    False
# 2998    False
# 2999    False
# Name: population, Length: 3000, dtype: bool

# %%
c1 = df['median_house_value'] < 200000
c2 = df['median_income'] < 3

df[ c1 & c2 ]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4       -119.67     36.33                19.0       1241.0           244.0
# 5       -119.56     36.51                37.0       1018.0           213.0
# 6       -121.43     38.63                43.0       1009.0           225.0
# 9       -118.02     34.08                31.0       2402.0           632.0
# 10      -118.24     33.98                45.0        972.0           249.0
# ...         ...       ...                 ...          ...             ...
# 2984    -117.59     33.88                13.0       3239.0           849.0
# 2985    -120.47     34.94                17.0       1368.0           308.0
# 2986    -118.25     33.93                42.0        819.0           233.0
# 2990    -118.23     34.09                49.0       1638.0           456.0
# 2997    -119.70     36.30                10.0        956.0           201.0
#
#       population  households  median_income  median_house_value
# ...

# %%
c1 = df['total_rooms'] > 3000
c2 = df['total_bedrooms'] > 300

df[c1 | c2]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 7       -120.65     35.48                19.0       2310.0           471.0
# 8       -122.84     38.40                15.0       3080.0           617.0
# ...         ...       ...                 ...          ...             ...
# 2990    -118.23     34.09                49.0       1638.0           456.0
# 2991    -117.17     34.28                13.0       4867.0           718.0
# 2993    -117.91     33.60                37.0       2088.0           510.0
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df[ (df['total_rooms'] > 3000) | (df['total_bedrooms'] > 300) ]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 7       -120.65     35.48                19.0       2310.0           471.0
# 8       -122.84     38.40                15.0       3080.0           617.0
# ...         ...       ...                 ...          ...             ...
# 2990    -118.23     34.09                49.0       1638.0           456.0
# 2991    -117.17     34.28                13.0       4867.0           718.0
# 2993    -117.91     33.60                37.0       2088.0           510.0
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
#
#       population  households  median_income  median_house_value
# ...

# %%
#The dataframes are IMMUTABLE

c = df['population'] < 300
df[c]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3       -118.36     33.82                28.0         67.0            15.0
# 15      -117.99     33.81                42.0        161.0            40.0
# 16      -120.81     37.53                15.0        570.0           123.0
# 115     -118.85     34.17                42.0        564.0            96.0
# 119     -118.41     34.00                38.0        324.0            70.0
# ...         ...       ...                 ...          ...             ...
# 2869    -117.43     33.55                 8.0        446.0            62.0
# 2879    -121.84     38.02                46.0         66.0            22.0
# 2929    -117.23     32.74                16.0        735.0           139.0
# 2992    -122.33     37.39                52.0        573.0           102.0
# 2998    -117.12     34.10                40.0         96.0            14.0
#
#       population  households  median_income  median_house_value
# ...

# %%
c = df['population'] < 300
population_less_than_300 = df[c]
population_less_than_300
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3       -118.36     33.82                28.0         67.0            15.0
# 15      -117.99     33.81                42.0        161.0            40.0
# 16      -120.81     37.53                15.0        570.0           123.0
# 115     -118.85     34.17                42.0        564.0            96.0
# 119     -118.41     34.00                38.0        324.0            70.0
# ...         ...       ...                 ...          ...             ...
# 2869    -117.43     33.55                 8.0        446.0            62.0
# 2879    -121.84     38.02                46.0         66.0            22.0
# 2929    -117.23     32.74                16.0        735.0           139.0
# 2992    -122.33     37.39                52.0        573.0           102.0
# 2998    -117.12     34.10                40.0         96.0            14.0
#
#       population  households  median_income  median_house_value
# ...

# %%
c1 = df['housing_median_age'] > 40
c2 = df['households'] > 200
c3 = df['median_income'] < 5

df[c1 | c2 & c3]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1       -118.30     34.26                43.0       1510.0           310.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# 5       -119.56     36.51                37.0       1018.0           213.0
# 6       -121.43     38.63                43.0       1009.0           225.0
# 7       -120.65     35.48                19.0       2310.0           471.0
# ...         ...       ...                 ...          ...             ...
# 2992    -122.33     37.39                52.0        573.0           102.0
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
c1 = df['housing_median_age'] > 40
c2 = df['households'] > 200
c3 = df['median_income'] < 5

df[ (c1 | c2) & c3]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1       -118.30     34.26                43.0       1510.0           310.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# 5       -119.56     36.51                37.0       1018.0           213.0
# 6       -121.43     38.63                43.0       1009.0           225.0
# 7       -120.65     35.48                19.0       2310.0           471.0
# ...         ...       ...                 ...          ...             ...
# 2989    -122.02     37.60                32.0       1295.0           295.0
# 2990    -118.23     34.09                49.0       1638.0           456.0
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
#
#       population  households  median_income  median_house_value
# ...

# %%
#Agregat

df["population"]
# Out:
# 0       1537.0
# 1        809.0
# 2       1484.0
# 3         49.0
# 4        850.0
#          ...
# 2995    1258.0
# 2996    3496.0
# 2997     693.0
# 2998      46.0
# 2999     753.0
# Name: population, Length: 3000, dtype: float64

# %%
df['population'].sum()
# Out:
# 4208396.0

# %%
c = df['population'] > 600
df[c]['population'].sum()
# Out:
# 4040391.0

# %%
df.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
# longitude             3000 non-null float64
# latitude              3000 non-null float64
# housing_median_age    3000 non-null float64
# total_rooms           3000 non-null float64
# total_bedrooms        3000 non-null float64
# population            3000 non-null float64
# households            3000 non-null float64
# median_income         3000 non-null float64
# median_house_value    3000 non-null float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
import xlrd as xlrd
df = pd.read_excel('crmrop.xlsx')
